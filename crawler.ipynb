# %%
### A crawler for DIVAR.IR using its POST API

# %%
import requests
import json
import math
from bs4 import BeautifulSoup as BS4
import csv

# %%
## Fetch City Lists and Categories\
root_URL = 'https://divar.ir/s/tehran'
root_response = requests.get(root_URL)

parsed_root_reponse = BS4(root_response.text, 'html.parser')
preload_data = parsed_root_reponse.find_all('script')

# %%
preload_indx = -1
for i , val in enumerate(preload_data):
    if len(val.contents) == 1 and 'window.__PRELOADED_STATE__' in val.string:
        preload_indx = i
        
## find the first and last { }
start = preload_data[preload_indx].string.find('{')
end = preload_data[preload_indx].string.rfind('}')

preload_js = json.loads(preload_data[preload_indx].string[start : end + 1])

# %%
def find_city(city_name):
    for state in preload_js["multiCity"]["data"]["children"]:
        for city in state["children"]:
            if city["name"] == city_name:
                return city["id"]

    return -1

def find_category(category_name):
    for category in preload_js["search"]["rootCat"]["children"]:
        if category["name"] == category_name:
            return category["slug"]

        else:
            for sub_cat in category["children"]:
                if sub_cat["name"] == category_name:
                    return sub_cat["slug"]

    return -1

# %%
list_of_city_names = ['تهران' , 'اصفهان', 'شیراز']
categorie = 'وسایل نقلیه'
query = "پژو ۲۰۶"
pages_to_load = 4

city_ids = []
for city_name in list_of_city_names:
    city_ids.append( str(find_city(city_nfame)) )

categorie_slug = find_category(categorie)

print(f'Search for: {query} in Cities: {list_of_city_names} and in the Category: {categorie}, retrive {pages_to_load} pages')
# Out:
# Search for: پژو ۲۰۶ in Cities: ['تهران', 'اصفهان', 'شیراز'] and in the Category: وسایل نقلیه, retrive 4 pages

# %%
## Create Payload
payload = {
    "city_ids": city_ids,
    "pagination_data":{"@type":"type.googleapis.com/post_list.PaginationData","page":0,"layer_page":0},
    "search_data":{"form_data":{"data":{"category":{"str":{"value":categorie_slug}},"sort":{"str":{"value":"sort_date"}}}}, "query" : query}
}

req_url = "https://api.divar.ir/v8/postlist/w/search"

responses = []
for i in range(1, pages_to_load + 1):

    payload["pagination_data"]["page"] = i
    payload["pagination_data"]["layer_page"] = i
    
    response = requests.post(req_url , data = json.dumps(payload))
    if response.ok:
        responses.append( response.json() )
        
print(f'You got {len(responses)} OK responses')
# Out:
# You got 4 OK responses

# %%
## Clean Up the Data
collected_data = []
adver_url = "https://divar.ir/v/"

for resp in responses:
    for widget in resp["list_widgets"]:
        if widget["widget_type"] == "POST_ROW":
            collected_data.append({
                "name"  : widget["data"]["title"],
                "url": adver_url + widget["data"]["title"].replace(' ', '-') + "/" + widget["data"]["action"]["payload"]["token"],
                "token" : widget["data"]["action"]["payload"]["token"],
                "price" : widget["data"]["middle_description_text"] if "middle_description_text" in  widget["data"].keys() else "-1",
                "city"  : widget["data"]["action"]["payload"]["web_info"]["city_persian"],
                "desc"  : widget["data"]["top_description_text"] if "top_description_text" in  widget["data"].keys() else "-1"
            })

# %%
## in collected data, search for full description in the ad page
url_head = "https://api.divar.ir/v8/posts-v2/web/"

for i , data in enumerate(collected_data):
    token = data["token"]
    response = requests.get(url_head + token)

    if response.ok:
        colected = response.json()
        description = colected["seo"]["description"]
        collected_data[i]["full_desc"] = description

# %%
## convert prices to intigers
def convert_str_to_int(string):
    if string == "-1":
        return -1
    number = string[:-6]
    number = number.replace(',' , '')
    return int(number)

# %%
for i , data in enumerate(collected_data):
    collected_data[i]["price"] = convert_str_to_int(data["price"])

# %%
for data in collected_data:
    print("name:" , '\t' , data["name"])
    print("url:" , '\t' ,  data["url"])
    print("token:" , '\t' , data["token"])
    print("price:" , '\t' , data["price"])
    print("city:" , '\t' , data["city"])
    print("desc:" , '\t' , data["desc"])
    print('___________________________________________________________________________________________\n')
# Out:
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۵
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۵/gZhykLpm
# token: 	 gZhykLpm
# price: 	 400000000
# city: 	 اصفهان
# desc: 	 ۸۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۷/gZhyEELx
# token: 	 gZhyEELx
# price: 	 455000000
# city: 	 شیراز
# desc: 	 ۱۰۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۶/gZhS0vZz
# token: 	 gZhS0vZz
# price: 	 485000000
# city: 	 تهران
# desc: 	 ۸۱,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 ۲۰۶تیپ ۲ اتاق تعویض۱۴۰۰
# url: 	 https://divar.ir/v/۲۰۶تیپ-۲-اتاق-تعویض۱۴۰۰/gZXaXNAc
# token: 	 gZXaXNAc
# price: 	 339000000
# city: 	 تهران
# desc: 	 ۸۶,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۳ پانوراما، مدل ۱۴۰۱
# url: 	 https://divar.ir/v/پژو-206-تیپ-۳-پانوراما،-مدل-۱۴۰۱/gZhukKy4
# token: 	 gZhukKy4
# price: 	 565000000
# city: 	 تهران
# desc: 	 ۲۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۶، مدل ۱۳۸۴
# url: 	 https://divar.ir/v/پژو-206-تیپ-۶،-مدل-۱۳۸۴/gZhqkpWk
# token: 	 gZhqkpWk
# price: 	 370000000
# city: 	 تهران
# desc: 	 ۲۰۰,۱۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۴
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۴/gZhqEmdI
# token: 	 gZhqEmdI
# price: 	 198000000
# city: 	 تهران
# desc: 	 ۳۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۳، مدل ۱۳۸۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۳،-مدل-۱۳۸۷/gZhmkQDA
# token: 	 gZhmkQDA
# price: 	 262000000
# city: 	 تهران
# desc: 	 ۴۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 فنر
# url: 	 https://divar.ir/v/فنر/gZhiE4zj
# token: 	 gZhiE4zj
# price: 	 950000
# city: 	 اصفهان
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۹/gZhiUXCK
# token: 	 gZhiUXCK
# price: 	 470000000
# city: 	 تهران
# desc: 	 ۵۸,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۶/gZhi0Dpy
# token: 	 gZhi0Dpy
# price: 	 240000000
# city: 	 شیراز
# desc: 	 ۳۲۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۶/gZhe0-mc
# token: 	 gZhe0-mc
# price: 	 410000000
# city: 	 شیراز
# desc: 	 ۲۳۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 *خشک خشک صندوقدار V8* مدل آخر 1399
# url: 	 https://divar.ir/v/*خشک-خشک-صندوقدار-V8*-مدل-آخر-1399/QZEW5Cbc
# token: 	 QZEW5Cbc
# price: 	 111111111
# city: 	 تهران
# desc: 	 ۱,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۷/gZheURMI
# token: 	 gZheURMI
# price: 	 428000000
# city: 	 تهران
# desc: 	 ۶۹,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۸/gZhaUqo-
# token: 	 gZhaUqo-
# price: 	 430000000
# city: 	 تهران
# desc: 	 ۵۶,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۴۰۰
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۴۰۰/gZha0jit
# token: 	 gZha0jit
# price: 	 523000000
# city: 	 تهران
# desc: 	 ۴۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۴۰۰
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۴۰۰/gZhaEh-q
# token: 	 gZhaEh-q
# price: 	 525000000
# city: 	 تهران
# desc: 	 ۴۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۹/gZha0PPD
# token: 	 gZha0PPD
# price: 	 290000000
# city: 	 تهران
# desc: 	 ۱۷۲,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 کاپوت پژو پراید 206سمند111صبا132رنگی ضمانت دار
# url: 	 https://divar.ir/v/کاپوت-پژو-پراید-206سمند111صبا132رنگی-ضمانت-دار/gZhW0I8v
# token: 	 gZhW0I8v
# price: 	 1380000
# city: 	 تهران
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۹۶/gZhWEwSm
# token: 	 gZhWEwSm
# price: 	 510000000
# city: 	 تهران
# desc: 	 ۱۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V9، مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-SD-V9،-مدل-۱۳۸۹/gZhWkufR
# token: 	 gZhWkufR
# price: 	 300000000
# city: 	 شیراز
# desc: 	 ۴۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۳، مدل ۱۳۸۵
# url: 	 https://divar.ir/v/پژو-206-تیپ-۳،-مدل-۱۳۸۵/gZtZTe3b
# token: 	 gZtZTe3b
# price: 	 260000000
# city: 	 اصفهان
# desc: 	 ۲۲۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پراید 131 SE، مدل ۱۳۹۶ معاوضه پژو پرشیا ۲۰۶
# url: 	 https://divar.ir/v/پراید-131-SE،-مدل-۱۳۹۶-معاوضه-پژو-پرشیا-۲۰۶/gZklQylS
# token: 	 gZklQylS
# price: 	 265000000
# city: 	 تهران
# desc: 	 ۶۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 رام اکسل پراید پژو سمند 206 اصلی گلگیر
# url: 	 https://divar.ir/v/رام-اکسل-پراید-پژو-سمند-206-اصلی-گلگیر/gZhKUes9
# token: 	 gZhKUes9
# price: 	 480000
# city: 	 تهران
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۲
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۲/gZhKEo0W
# token: 	 gZhKEo0W
# price: 	 200000000
# city: 	 اصفهان
# desc: 	 ۴۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۰
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۰/gZVOV0kc
# token: 	 gZVOV0kc
# price: 	 190000000
# city: 	 شیراز
# desc: 	 ۱۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۹/gZCy-clZ
# token: 	 gZCy-clZ
# price: 	 260000000
# city: 	 اصفهان
# desc: 	 ۲۲۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو۲۰۶تیپ۵مدل۹۳
# url: 	 https://divar.ir/v/پژو۲۰۶تیپ۵مدل۹۳/gZhqT9uG
# token: 	 gZhqT9uG
# price: 	 385000000
# city: 	 تهران
# desc: 	 ۹۹,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۸/gZhGEQH6
# token: 	 gZhGEQH6
# price: 	 445000000
# city: 	 تهران
# desc: 	 ۱۱۱,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۸۹/gZhGUIHa
# token: 	 gZhGUIHa
# price: 	 270000000
# city: 	 اصفهان
# desc: 	 ۳۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۹/gZhCk3yp
# token: 	 gZhCk3yp
# price: 	 485000000
# city: 	 تهران
# desc: 	 ۴۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۴۰۱
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۴۰۱/gZhCEDt_
# token: 	 gZhCEDt_
# price: 	 568000000
# city: 	 تهران
# desc: 	 ۲۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206SD، دوگانه ۸۷ ، موتور بزرگ فرانسوی
# url: 	 https://divar.ir/v/پژو-206SD،-دوگانه-۸۷-،-موتور-بزرگ-فرانسوی/gZAqh_BN
# token: 	 gZAqh_BN
# price: 	 338000000
# city: 	 تهران
# desc: 	 ۱۹۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۳
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۳/gZh-zx_1
# token: 	 gZh-zx_1
# price: 	 402000000
# city: 	 تهران
# desc: 	 ۲۳۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۹۴
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۹۴/gZh-DROB
# token: 	 gZh-DROB
# price: 	 415000000
# city: 	 تهران
# desc: 	 ۲۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۹۴
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۹۴/gZh6j4UN
# token: 	 gZh6j4UN
# price: 	 398000000
# city: 	 تهران
# desc: 	 ۹۲,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۳
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۳/gZfmnULR
# token: 	 gZfmnULR
# price: 	 460000000
# city: 	 تهران
# desc: 	 ۴۶,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۶/gZh-S-I4
# token: 	 gZh-S-I4
# price: 	 410000000
# city: 	 شیراز
# desc: 	 ۱۷۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۰
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۰/gZhCD1Ip
# token: 	 gZhCD1Ip
# price: 	 320000000
# city: 	 تهران
# desc: 	 ۳۸۸,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۳ پانوراما، مدل ۱۴۰۱
# url: 	 https://divar.ir/v/پژو-206-تیپ-۳-پانوراما،-مدل-۱۴۰۱/gZZSj7dX
# token: 	 gZZSj7dX
# price: 	 558000000
# city: 	 تهران
# desc: 	 ۵۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۴ نقد و اقساط
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۴-نقد-و-اقساط/gZCSO4YG
# token: 	 gZCSO4YG
# price: 	 200000000
# city: 	 تهران
# desc: 	 ۳۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۶/gZh2zhEN
# token: 	 gZh2zhEN
# price: 	 440000000
# city: 	 شیراز
# desc: 	 ۵۴,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۴ بدون رنگ
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۴-بدون-رنگ/gZZ2Upu7
# token: 	 gZZ2Upu7
# price: 	 415000000
# city: 	 اصفهان
# desc: 	 ۱۲۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۳
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۳/gZh2TZQy
# token: 	 gZh2TZQy
# price: 	 220000000
# city: 	 اصفهان
# desc: 	 ۴۲۱,۸۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۴۰۱
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۴۰۱/gZeeGD2e
# token: 	 gZeeGD2e
# price: 	 555000000
# city: 	 تهران
# desc: 	 ۹,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 جلو پنجره ،شمع،سوپاپ
# url: 	 https://divar.ir/v/جلو-پنجره-،شمع،سوپاپ/gZh2jJtY
# token: 	 gZh2jJtY
# price: 	 70000
# city: 	 تهران
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۳
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۳/gZhyz1S-
# token: 	 gZhyz1S-
# price: 	 205000000
# city: 	 اصفهان
# desc: 	 ۴۷۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۹/gZhuT8cy
# token: 	 gZhuT8cy
# price: 	 530000000
# city: 	 تهران
# desc: 	 ۲۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 توربین گیربکس اتومات پراید و پژو  ساعتی گیربکس
# url: 	 https://divar.ir/v/توربین-گیربکس-اتومات-پراید-و-پژو--ساعتی-گیربکس/AZgb3EO-
# token: 	 AZgb3EO-
# price: 	 6000000
# city: 	 تهران
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V6، مدل ۱۳۸۸
# url: 	 https://divar.ir/v/پژو-206-SD-V6،-مدل-۱۳۸۸/gZhuDZRn
# token: 	 gZhuDZRn
# price: 	 305000000
# city: 	 تهران
# desc: 	 ۲۲۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۸۶
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۸۶/gZhuTTHB
# token: 	 gZhuTTHB
# price: 	 280000000
# city: 	 تهران
# desc: 	 ۲۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۹۸/gZhuzJ_U
# token: 	 gZhuzJ_U
# price: 	 500000000
# city: 	 تهران
# desc: 	 ۱۰۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۵
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۵/gZhqjTDn
# token: 	 gZhqjTDn
# price: 	 450000000
# city: 	 تهران
# desc: 	 ۱۹۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۴
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۴/gZhqzeA3
# token: 	 gZhqzeA3
# price: 	 175000000
# city: 	 تهران
# desc: 	 ۳۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۳ پانوراما، مدل ۱۴۰۱
# url: 	 https://divar.ir/v/پژو-206-تیپ-۳-پانوراما،-مدل-۱۴۰۱/gZhSziEQ
# token: 	 gZhSziEQ
# price: 	 570000000
# city: 	 تهران
# desc: 	 ۱۴,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206، مدل ۱۳۹۷
# url: 	 https://divar.ir/v/پژو-206،-مدل-۱۳۹۷/gZhmDpOH
# token: 	 gZhmDpOH
# price: 	 445000000
# city: 	 تهران
# desc: 	 ۹۲,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۹/gZhmjaJo
# token: 	 gZhmjaJo
# price: 	 285000000
# city: 	 اصفهان
# desc: 	 ۲۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۹۰
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۹۰/gZhmjOuX
# token: 	 gZhmjOuX
# price: 	 300000000
# city: 	 تهران
# desc: 	 ۶۸,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۹/gZhiD7s2
# token: 	 gZhiD7s2
# price: 	 260000000
# city: 	 اصفهان
# desc: 	 ۲۹۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۷/gZhiTOQs
# token: 	 gZhiTOQs
# price: 	 160000000
# city: 	 اصفهان
# desc: 	 ۱۲۷,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۸/gZe-cnb0
# token: 	 gZe-cnb0
# price: 	 565000000
# city: 	 شیراز
# desc: 	 ۱۰۸,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۵ بیرنگ
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۵-بیرنگ/gZc2dq9V
# token: 	 gZc2dq9V
# price: 	 425000000
# city: 	 تهران
# desc: 	 ۱۱۶,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۵
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۵/gZhmSQVB
# token: 	 gZhmSQVB
# price: 	 250000000
# city: 	 تهران
# desc: 	 ۲۸۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۴۰۰
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۴۰۰/gZheTpGF
# token: 	 gZheTpGF
# price: 	 545000000
# city: 	 تهران
# desc: 	 ۲,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۸/gZhqSMmC
# token: 	 gZhqSMmC
# price: 	 475000000
# city: 	 تهران
# desc: 	 ۴۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۸/gZheDkGe
# token: 	 gZheDkGe
# price: 	 460000000
# city: 	 تهران
# desc: 	 ۸۱,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۴ آبی رویال کم کار درحد
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۴-آبی-رویال-کم-کار-درحد/gZa6WQBt
# token: 	 gZa6WQBt
# price: 	 400000000
# city: 	 تهران
# desc: 	 ۱۱۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 ۲۰۶ تیپ ۲ لا کاغذی
# url: 	 https://divar.ir/v/۲۰۶-تیپ-۲-لا-کاغذی/gZhezg0B
# token: 	 gZhezg0B
# price: 	 415000000
# city: 	 اصفهان
# desc: 	 ۱۳۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۲
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۲/gZhezb3u
# token: 	 gZhezb3u
# price: 	 175000000
# city: 	 تهران
# desc: 	 ۱۲۸,۸۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206مدل۱۳۹۵.قابل معاوضه
# url: 	 https://divar.ir/v/پژو-206مدل۱۳۹۵.قابل-معاوضه/gZhezaka
# token: 	 gZhezaka
# price: 	 111111111
# city: 	 شیراز
# desc: 	 ۲۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۹/gZhezGjR
# token: 	 gZhezGjR
# price: 	 485000000
# city: 	 تهران
# desc: 	 ۷۲,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ 2، مدل ۱۳۹۹ بی رنگ* تک برگ سند* کم کار
# url: 	 https://divar.ir/v/پژو-206-تیپ-2،-مدل-۱۳۹۹-بی-رنگ*-تک-برگ-سند*-کم-کار/gZhaz2Vh
# token: 	 gZhaz2Vh
# price: 	 445000000
# city: 	 تهران
# desc: 	 ۷۱,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۷/gZh6SdR2
# token: 	 gZh6SdR2
# price: 	 389000000
# city: 	 تهران
# desc: 	 ۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، فروش یا معاوضه با شاهین
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-فروش-یا-معاوضه-با-شاهین/gZh-Savq
# token: 	 gZh-Savq
# price: 	 425000000
# city: 	 تهران
# desc: 	 ۸۸,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۴۰۱
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۴۰۱/gZhaDqUG
# token: 	 gZhaDqUG
# price: 	 480000000
# city: 	 تهران
# desc: 	 ۷۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۳، مدل ۱۳۸۵
# url: 	 https://divar.ir/v/پژو-206-تیپ-۳،-مدل-۱۳۸۵/gZCiarjb
# token: 	 gZCiarjb
# price: 	 220000000
# city: 	 تهران
# desc: 	 ۲۶۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۴ مدل ۱۳۸۲ کاملا مشابه صفر
# url: 	 https://divar.ir/v/پژو-206-تیپ-۴-مدل-۱۳۸۲-کاملا-مشابه-صفر/gZNmYETE
# token: 	 gZNmYETE
# price: 	 987654321
# city: 	 تهران
# desc: 	 ۲۵,۲۴۱ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۹/gZhWjlrS
# token: 	 gZhWjlrS
# price: 	 425000000
# city: 	 تهران
# desc: 	 ۱۱۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V9، مدل ۱۳۸۸ کارکرد ۳۳۹۳۰۰
# url: 	 https://divar.ir/v/پژو-206-SD-V9،-مدل-۱۳۸۸-کارکرد-۳۳۹۳۰۰/gZhWTiD9
# token: 	 gZhWTiD9
# price: 	 310000000
# city: 	 تهران
# desc: 	 ۳۳۹,۳۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 فرانسوی نقره آبی متالیک tu3، مدل 81
# url: 	 https://divar.ir/v/پژو-206-فرانسوی-نقره-آبی-متالیک-tu3،-مدل-81/QZuPSmEC
# token: 	 QZuPSmEC
# price: 	 199000000
# city: 	 تهران
# desc: 	 ۲۲۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۳ پانوراما، مدل ۱۴۰۱
# url: 	 https://divar.ir/v/پژو-206-تیپ-۳-پانوراما،-مدل-۱۴۰۱/gZQayM99
# token: 	 gZQayM99
# price: 	 555000000
# city: 	 تهران
# desc: 	 ۱۱,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۸/gZhWCN7r
# token: 	 gZhWCN7r
# price: 	 442000000
# city: 	 اصفهان
# desc: 	 ۱۳۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۷/gZf-vL24
# token: 	 gZf-vL24
# price: 	 455000000
# city: 	 تهران
# desc: 	 ۶۶,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۹۶/gZXatFHL
# token: 	 gZXatFHL
# price: 	 398000000
# city: 	 اصفهان
# desc: 	 ۲۷۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۳، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۳،-مدل-۱۳۹۹/gZhOzmyK
# token: 	 gZhOzmyK
# price: 	 550000000
# city: 	 اصفهان
# desc: 	 ۱۷,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۶/gZhOzk74
# token: 	 gZhOzk74
# price: 	 405000000
# city: 	 تهران
# desc: 	 ۱۴۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۵
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۵/gZaaBmDh
# token: 	 gZaaBmDh
# price: 	 410000000
# city: 	 اصفهان
# desc: 	 ۱۵۹,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۷/gZfe7xa0
# token: 	 gZfe7xa0
# price: 	 258000000
# city: 	 تهران
# desc: 	 ۳۲۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۳
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۳/gZhKDJls
# token: 	 gZhKDJls
# price: 	 490000000
# city: 	 تهران
# desc: 	 ۱۶۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۵
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۵/gZdyPqGp
# token: 	 gZdyPqGp
# price: 	 420000000
# city: 	 تهران
# desc: 	 ۸۷,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۴۰۱
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۴۰۱/gZJekYxJ
# token: 	 gZJekYxJ
# price: 	 517000000
# city: 	 تهران
# desc: 	 ۲۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۳
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۳/gZhGzPgb
# token: 	 gZhGzPgb
# price: 	 225000000
# city: 	 تهران
# desc: 	 ۱۹۹,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۸/gZdq18Nd
# token: 	 gZdq18Nd
# price: 	 285000000
# city: 	 تهران
# desc: 	 ۱۲۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۴ همه چیز نو
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۴-همه-چیز-نو/gZhCzdkq
# token: 	 gZhCzdkq
# price: 	 395000000
# city: 	 تهران
# desc: 	 ۱۳۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۹۹/gZMCyYIN
# token: 	 gZMCyYIN
# price: 	 526000000
# city: 	 تهران
# desc: 	 ۶۲,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۶/gZh-yZco
# token: 	 gZh-yZco
# price: 	 465000000
# city: 	 تهران
# desc: 	 ۱۸۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________

# %%
## Write data to CSV file
with open("divar_data.csv", "w", newline="") as file:
    w = csv.DictWriter(file, collected_data[0].keys())
    w.writeheader()

    for data in collected_data:
        w.writerow(data)
